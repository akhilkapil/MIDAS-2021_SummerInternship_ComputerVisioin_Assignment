# %%
'''Basic Libraries'''
import pandas as pd 
import numpy as np 
from pathlib import Path
import matplotlib.pyplot as plt 
import os.path 
import regex as re
import warnings, idx2numpy, itertools, zipfile, math 
from PIL import Image

warnings.filterwarnings('ignore')


'''Preprocessing and CNN Libraries'''
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Conv2D, BatchNormalization, Activation, MaxPooling2D, Dropout, AveragePooling2D, Input, Flatten, add
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2, l1
from tensorflow.keras.models import Model,load_model
from tensorflow.keras.utils import to_categorical, plot_model
import tensorflow as tf 
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

# %%
with zipfile.ZipFile('/content/drive/MyDrive/mnistTask3.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/dataset')

# %%
test_img_path = '/content/drive/MyDrive/TEST_MNIST/t10k-images-idx3-ubyte.gz/t10k-images.idx3-ubyte'
test_label_path = '/content/drive/MyDrive/TEST_MNIST/t10k-labels-idx1-ubyte.gz/t10k-labels.idx1-ubyte'

# %%
#CONFIG 
TRAIN_DIR = '/content/dataset/mnistTask' 
NUM_CLASSES = 10
n = 3
BATCH_SIZE = 128
EPOCHS = 100
IMG_HEIGHT = 28 
IMG_WIDTH = 28
CHANNELS = 1
RANDOM_STATE = 2018

# %% [markdown]
# # __Data Collection and Preprocessing__
#
# __Converting Train images into n dimensional arrays__

# %%
filepaths = list(Path(TRAIN_DIR).glob(r'**/*.jpg'))
labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))
filepaths = pd.Series(filepaths, name='Filepath').astype(str)
labels = pd.Series(labels, name='Label')

#Concatenating filepaths and image labels into a dataframe
image_df = pd.concat([filepaths, labels], axis=1)
label_list = image_df['Label'].values.reshape(-1,1)

# Now We need to extract values of each pixel from our Images and store them in a ndarray so that our model can learn them better.
train_files = [] 
for _file in filepaths:
  train_files.append(_file) #Append the path names for each image 

dataset = np.ndarray(shape=(len(train_files), IMG_HEIGHT, IMG_WIDTH, CHANNELS), dtype=np.float32)

i=0
for _file in train_files:
  img = Image.open(_file)
  img = img.convert('L')
  img = np.expand_dims(img, axis=-1)
  dataset[i] = img
  i += 1

# %%
X_train, X_val, y_train, y_val = train_test_split(dataset, label_list, test_size=0.20, random_state=RANDOM_STATE)

# %% [markdown]
# __Converting MNIST test images into n dimensional arrays__

# %%
#extracting the iamges and converting them into arrays
test_images = idx2numpy.convert_from_file(test_img_path)

#Reshape all the images into (w,d,c)
test_images = test_images.reshape(len(test_images), IMG_HEIGHT, IMG_WIDTH, CHANNELS)

#same goes with labels
test_label = idx2numpy.convert_from_file(test_label_path)

test_label = test_label.reshape(-1,1)

# %%
# storing the inputs of image dimensions in a variable.
input_shape = X_train.shape[1:]

# normalizing data. As we want values to be scaled within a range of 0 to 255 because CNN converges faster on scale of 0 to 1 rather 
# then on a scale of 0 to 255.
X_train = X_train.astype('float32') / 255
X_val = X_val.astype('float32') / 255
test_images = test_images.astype('float32') / 255

# Subtracting pixel improves accuracy
x_train_mean = np.mean(X_train, axis=0)
x_test_mean = np.mean(X_val, axis=0)
test_images_mean = np.mean(test_images, axis=0)
X_train -= x_train_mean
X_val -= x_test_mean
test_images -= test_images_mean

print('x_train shape:', X_train.shape)
print(X_train.shape[0], 'train samples')
print(X_val.shape[0], 'test samples')
print('y_train shape:', y_train.shape)
# Out:
# x_train shape: (48000, 28, 28, 1)
# 48000 train samples
# 12000 test samples
# y_train shape: (48000, 1)

# %%
# convert class vectoars to binary class matrices.
y_train = to_categorical(y_train, NUM_CLASSES)
y_val = to_categorical(y_val, NUM_CLASSES)
test_label = to_categorical(test_label, NUM_CLASSES)

# %%
y_train.shape
# Out:
# (48000, 10)

# %%
# Perform data augmentation so that it done lead o overfitting

datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False, # divide inputs by std of dataset
        samplewise_std_normalization=False, # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=0,  # randomly rotate images in the range (deg 0 to 180)
        width_shift_range=0.1,  # randomly shift images horizontally
        height_shift_range=0.1, # randomly shift images vertically
        horizontal_flip=True,   # randomly flip images horizontally
        vertical_flip=False)  # randomly flip images vertically

datagen.fit(X_train)

# How many images should each Epoch should consist.
steps_per_epoch =  math.ceil(len(X_train) / BATCH_SIZE)

# %% [markdown]
# # Model Building
#
# For this task I am using the same model from task 1 but training it from scratch and randomly initializing weighs again.
#
# The architecture of the model is quite same as it was for the part 1.

# %%
# Depth shows how deep the neural network should be built. 

version = 1
if version == 1:
    depth = n * 6 + 2
elif version == 2:
    depth = n * 9 + 2


def resnet_layer(inputs, 
                 num_filters=16, 
                 kernel_size=3, 
                 strides=1, 
                 activation = 'relu', 
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder
    Arguments:
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)
    Returns:
        x (tensor): tensor as input to the next layer
    """
    
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x
    
def resnet_v1(input_shape, depth, num_classes=NUM_CLASSES):
    """ResNet Version 1 Model builder [a]
    Stacks of 2 x (3 x 3) Conv2D-BN-ReLU
    Last ReLU is after the shortcut connection.
    At the beginning of each stage, the feature map size is halved
    (downsampled) by a convolutional layer with strides=2, while 
    the number of filters is doubled. Within each stage, 
    the layers have the same number filters and the
    same number of filters.
    Features maps sizes:
    stage 0: 32x32, 16
    stage 1: 16x16, 32
    stage 2:  8x8,  64
    The Number of parameters is approx the same as Table 6 of [a]:
    ResNet20 0.27M
    ResNet32 0.46M
    ResNet44 0.66M
    ResNet56 0.85M
    ResNet110 1.7M
    Arguments:
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)
    Returns:
        model (Model): Keras model instance
    """
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, in [a])')
    # start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            # first layer but not first stack
            if stack > 0 and res_block == 0:  
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            # first layer but not first stack
            if stack > 0 and res_block == 0:
                # linear projection residual shortcut
                # connection to match changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = AveragePooling2D(pool_size=4)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
#Crating a directory to save both the models 

save_dir = os.path.join(os.getcwd(), 'task_3_models_2.3.1')
pretrained_name = 'task231_pretrained_model.h5'
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
pretrained_filepath = os.path.join(save_dir,pretrained_name)

# %%
# Defining some Callbacks 

# For reusing the best model, I am defining a checkoint so that the model with the best learned parameters can be saved
checkpoint = ModelCheckpoint(filepath=pretrained_filepath,monitor='val_acc',verbose=1,save_best_only=True)

#Reducing the LR by sqrt(0.1) factor if the accuracy is not imporved after 5 epochs 
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),cooldown=0,patience=5,min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer]

# %%
model = resnet_v1(input_shape=input_shape, depth=depth)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 28, 28, 1)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 28, 28, 16)   160         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 28, 28, 16)   64          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 28, 28, 16)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 28, 28, 16)   2320        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 28, 28, 16)   64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 28, 28, 16)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 28, 28, 16)   2320        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 28, 28, 16)   64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 28, 28, 16)   0           activation[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 28, 28, 16)   0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 28, 28, 16)   2320        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 28, 28, 16)   64          conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 28, 28, 16)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 28, 28, 16)   2320        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 28, 28, 16)   64          conv2d_4[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 28, 28, 16)   0           activation_2[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 28, 28, 16)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 28, 28, 16)   2320        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 28, 28, 16)   64          conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 28, 28, 16)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 28, 28, 16)   2320        activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 28, 28, 16)   64          conv2d_6[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 28, 28, 16)   0           activation_4[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 28, 28, 16)   0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 14, 14, 32)   4640        activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 14, 14, 32)   128         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 14, 14, 32)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 14, 14, 32)   9248        activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 14, 14, 32)   544         activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 14, 14, 32)   128         conv2d_8[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 14, 14, 32)   0           conv2d_9[0][0]
#                                                                  batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 14, 14, 32)   0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 14, 14, 32)   9248        activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 14, 14, 32)   128         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 14, 14, 32)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 14, 14, 32)   9248        activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 14, 14, 32)   128         conv2d_11[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 14, 14, 32)   0           activation_8[0][0]
#                                                                  batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 14, 14, 32)   0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 14, 14, 32)   9248        activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 14, 14, 32)   128         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 14, 14, 32)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 14, 14, 32)   9248        activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 14, 14, 32)   128         conv2d_13[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 14, 14, 32)   0           activation_10[0][0]
#                                                                  batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 14, 14, 32)   0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 7, 7, 64)     18496       activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 7, 7, 64)     256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 7, 7, 64)     0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 7, 7, 64)     36928       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 7, 7, 64)     2112        activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 7, 7, 64)     256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 7, 7, 64)     0           conv2d_16[0][0]
#                                                                  batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 7, 7, 64)     0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 7, 7, 64)     36928       activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 7, 7, 64)     256         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 7, 7, 64)     0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 7, 7, 64)     36928       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 7, 7, 64)     256         conv2d_18[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 7, 7, 64)     0           activation_14[0][0]
#                                                                  batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 7, 7, 64)     0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 7, 7, 64)     36928       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 7, 7, 64)     256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 7, 7, 64)     0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 7, 7, 64)     36928       activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 7, 7, 64)     256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 7, 7, 64)     0           activation_16[0][0]
#                                                                  batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 7, 7, 64)     0           add_8[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 1, 1, 64)     0           activation_18[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 64)           0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           650         flatten[0][0]
# ==================================================================================================
# Total params: 274,154
# Trainable params: 272,778
# Non-trainable params: 1,376
# __________________________________________________________________________________________________

# %%
# Compiling our model and fitting it on our dataset
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(),
              metrics=['acc'])

history  = model.fit(x=datagen.flow(X_train, y_train, batch_size=BATCH_SIZE),
              verbose=1,
              epochs=EPOCHS,
              validation_data=(X_val, y_val),
              steps_per_epoch=steps_per_epoch,
              callbacks=callbacks)
# Out:
# Epoch 1/100
# 375/375 [==============================] - 33s 77ms/step - loss: 2.5540 - acc: 0.1060 - val_loss: 2.4482 - val_acc: 0.1110
#
# Epoch 00001: val_acc improved from -inf to 0.11100, saving model to /content/task_3_models_2.3.1/task231_pretrained_model.h5
# Epoch 2/100
# 375/375 [==============================] - 28s 75ms/step - loss: 2.4386 - acc: 0.1106 - val_loss: 2.4300 - val_acc: 0.1078
#
# Epoch 00002: val_acc did not improve from 0.11100
# Epoch 3/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.4129 - acc: 0.1109 - val_loss: 2.3938 - val_acc: 0.1126
#
# Epoch 00003: val_acc improved from 0.11100 to 0.11258, saving model to /content/task_3_models_2.3.1/task231_pretrained_model.h5
# Epoch 4/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.3899 - acc: 0.1117 - val_loss: 2.3771 - val_acc: 0.1142
#
# Epoch 00004: val_acc improved from 0.11258 to 0.11417, saving model to /content/task_3_models_2.3.1/task231_pretrained_model.h5
# Epoch 5/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.3693 - acc: 0.1118 - val_loss: 2.3595 - val_acc: 0.1114
#
# Epoch 00005: val_acc did not improve from 0.11417
# Epoch 6/100
# 375/375 [==============================] - 28s 75ms/step - loss: 2.3489 - acc: 0.1096 - val_loss: 2.3362 - val_acc: 0.1094
#
# Epoch 00006: val_acc did not improve from 0.11417
# Epoch 7/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.3319 - acc: 0.1104 - val_loss: 2.3189 - val_acc: 0.1140
#
# Epoch 00007: val_acc did not improve from 0.11417
# Epoch 8/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.3175 - acc: 0.1136 - val_loss: 2.3184 - val_acc: 0.1094
#
# Epoch 00008: val_acc did not improve from 0.11417
# Epoch 9/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.3048 - acc: 0.1124 - val_loss: 2.2996 - val_acc: 0.1105
#
# Epoch 00009: val_acc did not improve from 0.11417
# Epoch 10/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.2917 - acc: 0.1157 - val_loss: 2.3046 - val_acc: 0.1133
#
# Epoch 00010: val_acc did not improve from 0.11417
# Epoch 11/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.2829 - acc: 0.1108 - val_loss: 2.3021 - val_acc: 0.1075
#
# Epoch 00011: val_acc did not improve from 0.11417
# Epoch 12/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.2740 - acc: 0.1182 - val_loss: 2.2824 - val_acc: 0.1133
#
# Epoch 00012: val_acc did not improve from 0.11417
# Epoch 13/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.2679 - acc: 0.1136 - val_loss: 2.2806 - val_acc: 0.1071
#
# Epoch 00013: val_acc did not improve from 0.11417
# Epoch 14/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.2632 - acc: 0.1107 - val_loss: 2.2694 - val_acc: 0.1131
#
# Epoch 00014: val_acc did not improve from 0.11417
# Epoch 15/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.2579 - acc: 0.1128 - val_loss: 2.2936 - val_acc: 0.1129
#
# Epoch 00015: val_acc did not improve from 0.11417
# Epoch 16/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.2560 - acc: 0.1141 - val_loss: 2.2646 - val_acc: 0.1098
#
# Epoch 00016: val_acc did not improve from 0.11417
# Epoch 17/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.2520 - acc: 0.1146 - val_loss: 2.2587 - val_acc: 0.1066
#
# Epoch 00017: val_acc did not improve from 0.11417
# Epoch 18/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.2483 - acc: 0.1139 - val_loss: 2.2591 - val_acc: 0.1037
#
# Epoch 00018: val_acc did not improve from 0.11417
# Epoch 19/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.2491 - acc: 0.1156 - val_loss: 2.2535 - val_acc: 0.1096
#
# Epoch 00019: val_acc did not improve from 0.11417
# Epoch 20/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.2461 - acc: 0.1126 - val_loss: 2.2533 - val_acc: 0.1066
#
# Epoch 00020: val_acc did not improve from 0.11417
# Epoch 21/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.2434 - acc: 0.1145 - val_loss: 2.2683 - val_acc: 0.1127
#
# Epoch 00021: val_acc did not improve from 0.11417
# Epoch 22/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.2443 - acc: 0.1151 - val_loss: 2.2991 - val_acc: 0.1123
#
# Epoch 00022: val_acc did not improve from 0.11417
# Epoch 23/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.2387 - acc: 0.1146 - val_loss: 2.2489 - val_acc: 0.1079
#
# Epoch 00023: val_acc did not improve from 0.11417
# Epoch 24/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.2386 - acc: 0.1163 - val_loss: 2.2493 - val_acc: 0.1072
#
# Epoch 00024: val_acc did not improve from 0.11417
# Epoch 25/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.2389 - acc: 0.1182 - val_loss: 2.2544 - val_acc: 0.1068
#
# Epoch 00025: val_acc did not improve from 0.11417
# Epoch 26/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.2392 - acc: 0.1133 - val_loss: 2.2461 - val_acc: 0.1171
#
# Epoch 00026: val_acc improved from 0.11417 to 0.11708, saving model to /content/task_3_models_2.3.1/task231_pretrained_model.h5
# Epoch 27/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.2366 - acc: 0.1143 - val_loss: 2.2488 - val_acc: 0.1123
#
# Epoch 00027: val_acc did not improve from 0.11708
# Epoch 28/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.2369 - acc: 0.1170 - val_loss: 2.2597 - val_acc: 0.1148
#
# Epoch 00028: val_acc did not improve from 0.11708
# Epoch 29/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.2374 - acc: 0.1214 - val_loss: 2.2479 - val_acc: 0.1059
#
# Epoch 00029: val_acc did not improve from 0.11708
# Epoch 30/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.2346 - acc: 0.1147 - val_loss: 2.2527 - val_acc: 0.1100
#
# Epoch 00030: val_acc did not improve from 0.11708
# Epoch 31/100
# 375/375 [==============================] - 28s 75ms/step - loss: 2.2334 - acc: 0.1151 - val_loss: 2.2486 - val_acc: 0.1098
#
# Epoch 00031: val_acc did not improve from 0.11708
# Epoch 32/100
# 375/375 [==============================] - 28s 75ms/step - loss: 2.2288 - acc: 0.1176 - val_loss: 2.2335 - val_acc: 0.1108
#
# Epoch 00032: val_acc did not improve from 0.11708
# Epoch 33/100
# 375/375 [==============================] - 28s 75ms/step - loss: 2.2239 - acc: 0.1163 - val_loss: 2.2352 - val_acc: 0.1088
#
# Epoch 00033: val_acc did not improve from 0.11708
# Epoch 34/100
# 375/375 [==============================] - 28s 75ms/step - loss: 2.2236 - acc: 0.1178 - val_loss: 2.2326 - val_acc: 0.1059
#
# Epoch 00034: val_acc did not improve from 0.11708
# Epoch 35/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.2210 - acc: 0.1187 - val_loss: 2.2337 - val_acc: 0.1098
#
# Epoch 00035: val_acc did not improve from 0.11708
# Epoch 36/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.2213 - acc: 0.1192 - val_loss: 2.2356 - val_acc: 0.1067
#
# Epoch 00036: val_acc did not improve from 0.11708
# Epoch 37/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.2209 - acc: 0.1217 - val_loss: 2.2320 - val_acc: 0.1106
#
# Epoch 00037: val_acc did not improve from 0.11708
# Epoch 38/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.2182 - acc: 0.1230 - val_loss: 2.2286 - val_acc: 0.1127
#
# Epoch 00038: val_acc did not improve from 0.11708
# Epoch 39/100
# 375/375 [==============================] - 28s 75ms/step - loss: 2.2196 - acc: 0.1245 - val_loss: 2.2355 - val_acc: 0.1063
#
# Epoch 00039: val_acc did not improve from 0.11708
# Epoch 40/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.2195 - acc: 0.1232 - val_loss: 2.2337 - val_acc: 0.1079
#
# Epoch 00040: val_acc did not improve from 0.11708
# Epoch 41/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.2162 - acc: 0.1286 - val_loss: 2.2337 - val_acc: 0.1059
#
# Epoch 00041: val_acc did not improve from 0.11708
# Epoch 42/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.2158 - acc: 0.1226 - val_loss: 2.2326 - val_acc: 0.1117
#
# Epoch 00042: val_acc did not improve from 0.11708
# Epoch 43/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.2147 - acc: 0.1279 - val_loss: 2.2324 - val_acc: 0.1109
#
# Epoch 00043: val_acc did not improve from 0.11708
# Epoch 44/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.2141 - acc: 0.1249 - val_loss: 2.2312 - val_acc: 0.1105
#
# Epoch 00044: val_acc did not improve from 0.11708
# Epoch 45/100
# 375/375 [==============================] - 28s 75ms/step - loss: 2.2109 - acc: 0.1283 - val_loss: 2.2301 - val_acc: 0.1098
#
# Epoch 00045: val_acc did not improve from 0.11708
# Epoch 46/100
# 375/375 [==============================] - 28s 75ms/step - loss: 2.2106 - acc: 0.1265 - val_loss: 2.2311 - val_acc: 0.1117
#
# Epoch 00046: val_acc did not improve from 0.11708
# Epoch 47/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.2091 - acc: 0.1283 - val_loss: 2.2323 - val_acc: 0.1120
#
# Epoch 00047: val_acc did not improve from 0.11708
# Epoch 48/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.2074 - acc: 0.1310 - val_loss: 2.2318 - val_acc: 0.1109
#
# Epoch 00048: val_acc did not improve from 0.11708
# Epoch 49/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.2062 - acc: 0.1324 - val_loss: 2.2329 - val_acc: 0.1112
#
# Epoch 00049: val_acc did not improve from 0.11708
# Epoch 50/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.2053 - acc: 0.1297 - val_loss: 2.2337 - val_acc: 0.1108
#
# Epoch 00050: val_acc did not improve from 0.11708
# Epoch 51/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.2031 - acc: 0.1332 - val_loss: 2.2353 - val_acc: 0.1123
#
# Epoch 00051: val_acc did not improve from 0.11708
# Epoch 52/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.2037 - acc: 0.1313 - val_loss: 2.2346 - val_acc: 0.1123
#
# Epoch 00052: val_acc did not improve from 0.11708
# Epoch 53/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.2029 - acc: 0.1325 - val_loss: 2.2353 - val_acc: 0.1127
#
# Epoch 00053: val_acc did not improve from 0.11708
# Epoch 54/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.2009 - acc: 0.1379 - val_loss: 2.2352 - val_acc: 0.1130
#
# Epoch 00054: val_acc did not improve from 0.11708
# Epoch 55/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.2008 - acc: 0.1346 - val_loss: 2.2358 - val_acc: 0.1122
#
# Epoch 00055: val_acc did not improve from 0.11708
# Epoch 56/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.2041 - acc: 0.1337 - val_loss: 2.2361 - val_acc: 0.1126
#
# Epoch 00056: val_acc did not improve from 0.11708
# Epoch 57/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.2023 - acc: 0.1368 - val_loss: 2.2358 - val_acc: 0.1133
#
# Epoch 00057: val_acc did not improve from 0.11708
# Epoch 58/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.2015 - acc: 0.1357 - val_loss: 2.2366 - val_acc: 0.1134
#
# Epoch 00058: val_acc did not improve from 0.11708
# Epoch 59/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.2008 - acc: 0.1364 - val_loss: 2.2365 - val_acc: 0.1133
#
# Epoch 00059: val_acc did not improve from 0.11708
# Epoch 60/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.2001 - acc: 0.1364 - val_loss: 2.2368 - val_acc: 0.1140
#
# Epoch 00060: val_acc did not improve from 0.11708
# Epoch 61/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.2010 - acc: 0.1373 - val_loss: 2.2368 - val_acc: 0.1132
#
# Epoch 00061: val_acc did not improve from 0.11708
# Epoch 62/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.2015 - acc: 0.1355 - val_loss: 2.2369 - val_acc: 0.1123
#
# Epoch 00062: val_acc did not improve from 0.11708
# Epoch 63/100
# 375/375 [==============================] - 28s 75ms/step - loss: 2.2017 - acc: 0.1367 - val_loss: 2.2370 - val_acc: 0.1122
#
# Epoch 00063: val_acc did not improve from 0.11708
# Epoch 64/100
# 375/375 [==============================] - 28s 75ms/step - loss: 2.2034 - acc: 0.1329 - val_loss: 2.2370 - val_acc: 0.1124
#
# Epoch 00064: val_acc did not improve from 0.11708
# Epoch 65/100
# 375/375 [==============================] - 28s 75ms/step - loss: 2.2009 - acc: 0.1347 - val_loss: 2.2371 - val_acc: 0.1130
#
# Epoch 00065: val_acc did not improve from 0.11708
# Epoch 66/100
# 375/375 [==============================] - 28s 75ms/step - loss: 2.2012 - acc: 0.1368 - val_loss: 2.2371 - val_acc: 0.1129
#
# Epoch 00066: val_acc did not improve from 0.11708
# Epoch 67/100
# 375/375 [==============================] - 28s 75ms/step - loss: 2.2019 - acc: 0.1361 - val_loss: 2.2371 - val_acc: 0.1130
#
# Epoch 00067: val_acc did not improve from 0.11708
# Epoch 68/100
# 375/375 [==============================] - 28s 75ms/step - loss: 2.2006 - acc: 0.1349 - val_loss: 2.2371 - val_acc: 0.1127
#
# Epoch 00068: val_acc did not improve from 0.11708
# Epoch 69/100
# 375/375 [==============================] - 28s 75ms/step - loss: 2.2012 - acc: 0.1358 - val_loss: 2.2372 - val_acc: 0.1122
#
# Epoch 00069: val_acc did not improve from 0.11708
# Epoch 70/100
# 375/375 [==============================] - 28s 75ms/step - loss: 2.1994 - acc: 0.1354 - val_loss: 2.2372 - val_acc: 0.1127
#
# Epoch 00070: val_acc did not improve from 0.11708
# Epoch 71/100
# 375/375 [==============================] - 28s 75ms/step - loss: 2.2020 - acc: 0.1362 - val_loss: 2.2372 - val_acc: 0.1130
#
# Epoch 00071: val_acc did not improve from 0.11708
# Epoch 72/100
# 375/375 [==============================] - 28s 75ms/step - loss: 2.2017 - acc: 0.1345 - val_loss: 2.2373 - val_acc: 0.1129
#
# Epoch 00072: val_acc did not improve from 0.11708
# Epoch 73/100
# 375/375 [==============================] - 28s 75ms/step - loss: 2.2018 - acc: 0.1334 - val_loss: 2.2372 - val_acc: 0.1132
#
# Epoch 00073: val_acc did not improve from 0.11708
# Epoch 74/100
# 375/375 [==============================] - 28s 75ms/step - loss: 2.2013 - acc: 0.1363 - val_loss: 2.2372 - val_acc: 0.1123
#
# Epoch 00074: val_acc did not improve from 0.11708
# Epoch 75/100
# 375/375 [==============================] - 28s 75ms/step - loss: 2.2035 - acc: 0.1377 - val_loss: 2.2373 - val_acc: 0.1130
#
# Epoch 00075: val_acc did not improve from 0.11708
# Epoch 76/100
# 375/375 [==============================] - 28s 75ms/step - loss: 2.1990 - acc: 0.1364 - val_loss: 2.2373 - val_acc: 0.1133
#
# Epoch 00076: val_acc did not improve from 0.11708
# Epoch 77/100
# 375/375 [==============================] - 28s 75ms/step - loss: 2.2006 - acc: 0.1379 - val_loss: 2.2374 - val_acc: 0.1130
#
# Epoch 00077: val_acc did not improve from 0.11708
# Epoch 78/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.2018 - acc: 0.1357 - val_loss: 2.2374 - val_acc: 0.1135
#
# Epoch 00078: val_acc did not improve from 0.11708
# Epoch 79/100
# 375/375 [==============================] - 28s 75ms/step - loss: 2.2007 - acc: 0.1371 - val_loss: 2.2374 - val_acc: 0.1131
#
# Epoch 00079: val_acc did not improve from 0.11708
# Epoch 80/100
# 375/375 [==============================] - 28s 75ms/step - loss: 2.2020 - acc: 0.1346 - val_loss: 2.2375 - val_acc: 0.1129
#
# Epoch 00080: val_acc did not improve from 0.11708
# Epoch 81/100
# 375/375 [==============================] - 28s 75ms/step - loss: 2.2006 - acc: 0.1373 - val_loss: 2.2376 - val_acc: 0.1132
#
# Epoch 00081: val_acc did not improve from 0.11708
# Epoch 82/100
# 375/375 [==============================] - 28s 75ms/step - loss: 2.2005 - acc: 0.1375 - val_loss: 2.2375 - val_acc: 0.1136
#
# Epoch 00082: val_acc did not improve from 0.11708
# Epoch 83/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.2023 - acc: 0.1332 - val_loss: 2.2375 - val_acc: 0.1127
#
# Epoch 00083: val_acc did not improve from 0.11708
# Epoch 84/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.1994 - acc: 0.1393 - val_loss: 2.2374 - val_acc: 0.1132
#
# Epoch 00084: val_acc did not improve from 0.11708
# Epoch 85/100
# 375/375 [==============================] - 28s 74ms/step - loss: 2.2016 - acc: 0.1363 - val_loss: 2.2375 - val_acc: 0.1133
#
# Epoch 00085: val_acc did not improve from 0.11708
# Epoch 86/100
# 375/375 [==============================] - 28s 75ms/step - loss: 2.1995 - acc: 0.1379 - val_loss: 2.2375 - val_acc: 0.1132
#
# Epoch 00086: val_acc did not improve from 0.11708
# Epoch 87/100
# 375/375 [==============================] - 28s 75ms/step - loss: 2.2000 - acc: 0.1390 - val_loss: 2.2375 - val_acc: 0.1130
#
# Epoch 00087: val_acc did not improve from 0.11708
# Epoch 88/100
# 375/375 [==============================] - 28s 75ms/step - loss: 2.2012 - acc: 0.1337 - val_loss: 2.2376 - val_acc: 0.1130
#
# Epoch 00088: val_acc did not improve from 0.11708
# Epoch 89/100
# 375/375 [==============================] - 28s 75ms/step - loss: 2.2009 - acc: 0.1378 - val_loss: 2.2375 - val_acc: 0.1132
#
# Epoch 00089: val_acc did not improve from 0.11708
# Epoch 90/100
# 375/375 [==============================] - 28s 75ms/step - loss: 2.2003 - acc: 0.1358 - val_loss: 2.2376 - val_acc: 0.1137
#
# Epoch 00090: val_acc did not improve from 0.11708
# Epoch 91/100
# 375/375 [==============================] - 28s 75ms/step - loss: 2.2013 - acc: 0.1339 - val_loss: 2.2376 - val_acc: 0.1130
#
# Epoch 00091: val_acc did not improve from 0.11708
# Epoch 92/100
# 375/375 [==============================] - 28s 76ms/step - loss: 2.2006 - acc: 0.1361 - val_loss: 2.2376 - val_acc: 0.1134
#
# Epoch 00092: val_acc did not improve from 0.11708
# Epoch 93/100
# 375/375 [==============================] - 28s 75ms/step - loss: 2.1994 - acc: 0.1398 - val_loss: 2.2376 - val_acc: 0.1132
#
# Epoch 00093: val_acc did not improve from 0.11708
# Epoch 94/100
# 375/375 [==============================] - 28s 75ms/step - loss: 2.2014 - acc: 0.1355 - val_loss: 2.2377 - val_acc: 0.1133
#
# Epoch 00094: val_acc did not improve from 0.11708
# Epoch 95/100
# 375/375 [==============================] - 28s 75ms/step - loss: 2.2007 - acc: 0.1366 - val_loss: 2.2377 - val_acc: 0.1137
#
# Epoch 00095: val_acc did not improve from 0.11708
# Epoch 96/100
# 375/375 [==============================] - 28s 75ms/step - loss: 2.1992 - acc: 0.1379 - val_loss: 2.2377 - val_acc: 0.1133
#
# Epoch 00096: val_acc did not improve from 0.11708
# Epoch 97/100
# 375/375 [==============================] - 28s 75ms/step - loss: 2.1993 - acc: 0.1382 - val_loss: 2.2377 - val_acc: 0.1131
#
# Epoch 00097: val_acc did not improve from 0.11708
# Epoch 98/100
# 375/375 [==============================] - 28s 76ms/step - loss: 2.1989 - acc: 0.1359 - val_loss: 2.2376 - val_acc: 0.1121
#
# Epoch 00098: val_acc did not improve from 0.11708
# Epoch 99/100
# 375/375 [==============================] - 28s 75ms/step - loss: 2.2016 - acc: 0.1373 - val_loss: 2.2378 - val_acc: 0.1126
#
# Epoch 00099: val_acc did not improve from 0.11708
# Epoch 100/100
# 375/375 [==============================] - 28s 75ms/step - loss: 2.2003 - acc: 0.1356 - val_loss: 2.2377 - val_acc: 0.1133
#
# Epoch 00100: val_acc did not improve from 0.11708

# %% [markdown]
# # __Evaluating Performance__

# %%
def display_training_curves(training, validation, title, subplot):
  ax = plt.subplot(subplot)
  ax.plot(training)
  ax.plot(validation)
  ax.set_title('model '+ title)
  ax.set_ylabel(title)
  ax.set_xlabel('epoch')
  ax.legend(['training', 'validation'])

plt.subplots(figsize=(10,10))
plt.tight_layout()
display_training_curves(history.history['acc'], history.history['val_acc'], 'accuracy', 211)
display_training_curves(history.history['loss'], history.history['val_loss'], 'loss', 212)

# %% [markdown]
# Checking the test accuracy for MNIST Test dataset

# %%
#Lets check the score for our model
model_score = model.evaluate(test_images, test_label)
print('The loss and val accuracy for model one is {} and {}'.format(model_score[0], model_score[1]))
# Out:
# 313/313 [==============================] - 4s 10ms/step - loss: 8.4143 - acc: 9.0000e-04
# The loss and val accuracy for model one is 8.414315223693848 and 0.0008999999845400453

# %%
#lets also check the misclassificaion error
#We are simpaly going to check out how our model has performed in identifying the right label for each of the images present in 
#test dataset

def prdict_right_classes(model, images, labels):
    predicted_classes = model.predict(images)
    prediction = np.argmax(predicted_classes, axis=-1)
    class_idx = np.argmax(labels, axis=-1)

    #compare them wether they are rightly classifid or not
    correct = np.nonzero(prediction==class_idx)[0]
    incorrect = np.nonzero(prediction!=class_idx)[0]
    return correct.shape[0], incorrect.shape[0]

model_preds = prdict_right_classes(model, test_images, test_label)
print('Correct predictions: {} | Incorrect Predictions: {}'.format(model_preds[0], model_preds[1]))
# Out:
# Correct predictions: 9 | Incorrect Predictions: 9991

# %% [markdown]
# __Observations:__
#
# - The result is quite obvious because of the noisy dataset.
# - Although, our model was able to predict 9 classes correctly.

# %% [markdown]
# ### I was a little bit skeptical about this question as we were being told to use pretrained model from scratch and provide test accuracy.
#
# ### So two methods were coming to my mind:
# #### 1. Taking this whole noisy dataset as our training dataset and using MNIST test dataset as our validation dataset.
# #### 2. Splitting this dataset into train and validation dataset and than using the trained model to on MNIST dataset and than providing the test accuracy.
#
# I didn't want to left out on any part, so I went away with both these methods.
